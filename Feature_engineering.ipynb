# %%
import pandas as pd 
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import text

# %%
dataset = pd.read_csv("Processed_data.csv")
dataset.head(2)
# Out:
#    Uniq Id  Product Id                                   Product Category  \
# 0      752        4489  Premium Beauty > Premium Makeup > Premium Nail...
# 1     3830        3370  Beauty > Hair Care > Hair Color > Auburn Hair ...
#
#   Product Brand                                       Product Name  \
# 0           OPI  OPI Infinite Shine, Nail Lacquer Nail Polish, ...
# 1   Nice'n Easy  Nice n Easy Permanent Color, 111 Natural Mediu...
#
#    Product Price                                Product Description  \
# 0           8.95                                                NaN
# 1          29.86  Pack of 3 Pack of 3 for the UPC: 381519000201 ...
#
#   Product Currency                                       Product Tags  \
# 0              USD  OPI Infinite Shine, Nail Lacquer Nail Polish, ...
# 1              USD  Nice 'n Easy Permanent Color, 111 Natural Medi...
#
#    Product Reviews Count  Crawl_date Crawl_time  rating_for_model  \
# 0              29.073529  2020-09-24   03:21:12          4.218750
# 1            6998.333333  2020-10-30   14:04:08          3.966667
#
#                               Product_image_Url_jpeg
# 0  https://i5.walmartimages.com/asr/0e1f4c51-c1a4...
# 1  https://i5.walmartimages.com/asr/9c8e42e4-13a5...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Uniq Id                 5000 non-null   int64
#  1   Product Id              5000 non-null   int64
#  2   Product Category        5000 non-null   object
#  3   Product Brand           5000 non-null   object
#  4   Product Name            5000 non-null   object
#  5   Product Price           5000 non-null   float64
#  6   Product Description     3873 non-null   object
#  7   Product Currency        5000 non-null   object
#  8   Product Tags            5000 non-null   object
#  9   Product Reviews Count   5000 non-null   float64
#  10  Crawl_date              5000 non-null   object
#  11  Crawl_time              5000 non-null   object
#  12  rating_for_model        5000 non-null   float64
#  13  Product_image_Url_jpeg  5000 non-null   object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 547.0+ KB

# %%
engine = create_engine("postgresql+psycopg2://postgres:root@localhost:5432/postgres")

# %%
# Creating a feature for popularity score 

## It help us to check between quality and quantity of reviews

# %%
# here are creating a column which is popularity score 
popularity_sql = """
ALTER TABLE products 
ADD COLUMN IF NOT EXISTS popularity_score DOUBLE PRECISION ;
"""
with engine.begin() as conn :
    conn.execute(text(popularity_sql))


## putting the calculated value in it 

update_popularity_sql = """
UPDATE products 
SET popularity_score = rating_for_model * LN(1 + "product_reviews_count")
"""

with engine.begin() as conn :
    conn.execute(text(update_popularity_sql))

# %%
## Calculating brand and category mean rating

# %%
mean_columns = """
ALTER TABLE products 
ADD COLUMN IF NOT EXISTS brand_mean_rating DOUBLE PRECISION
"""
with engine.begin() as conn :
    conn.execute(text(mean_columns))


## calculating the brand mean rating 

brand_mean_rating = """

WITH brand_avg AS (
SELECT "product_brand" AS brand , AVG(rating_for_model) AS avg_rating FROM products 
GROUP BY "product_brand"
)

UPDATE products p 
SET brand_mean_rating = b.avg_rating FROM brand_avg b 
WHERE p."product_brand" = b."brand";
"""

with engine.begin() as conn:
    conn.execute(text(brand_mean_rating))

# %%
## now for category mean rating

# %%
ean_columns = """
ALTER TABLE products 
ADD COLUMN IF NOT EXISTS category_mean_rating DOUBLE PRECISION;
"""

with engine.begin() as conn:
    conn.execute(text(mean_columns))


# Calculate category mean rating
category_mean_rating_sql = """
WITH avg_cat AS (SELECT "product_category" AS cat, AVG(rating_for_model) AS avg_rating FROM products
GROUP BY "product_category"
)
UPDATE products p
SET category_mean_rating = c.avg_rating FROM avg_cat c
WHERE p."product_category" = c.cat;
"""

with engine.begin() as conn:
    conn.execute(text(category_mean_rating_sql))

# %%
## Time based Features

# %%
add_time_columns = """
ALTER TABLE products
ADD COLUMN IF NOT EXISTS crawl_month INT,
ADD COLUMN IF NOT EXISTS crawl_dayofweek INT;
"""
with engine.begin() as conn :
    conn.execute(text(add_time_columns))
    

update_time_columns_sql = """
UPDATE products
SET crawl_month = EXTRACT(MONTH FROM "crawl_date"),
    crawl_dayofweek = EXTRACT(DOW FROM "crawl_date");
"""
with engine.begin() as conn:
    conn.execute(text(update_time_columns_sql))

# %%
featured_dataset = pd.read_sql("SELECT * FROM products;", engine)

# %%
featured_dataset["product_description"].fillna("", inplace = True)
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_25356\24333436.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   featured_dataset["product_description"].fillna("", inplace = True)

# %%
featured_dataset.head(3)
# Out:
#    uniq_id  product_id                                   product_category  \
# 0     2612         971  Premium Beauty > Premium Makeup > Premium Lips...
# 1     3524        2947  Premium Beauty > Premium Makeup > Premium Nail...
# 2      219        4388  Beauty > Beauty by Top Brands > L'Oreal > L'Or...
#
#    product_brand                                       product_name  \
# 0           NARS       NARS Velvet Matte Lip Pencil, Endangered Red
# 1            OPI  OPI Nail Polish Lacquer Holiday Hello Kitty .5...
# 2  L'Oreal Paris        Loreal Colour Riche Lipstick 183 pink vinyl
#
#    product_price                           product_description  \
# 0          11.25
# 1          10.95
# 2           6.41  183 pink vinylLp Generic Loreal Paris Colou.
#
#   product_currency                                       product_tags  \
# 0              USD  NARS Velvet Matte Lip Pencil, Endangered Red, ...
# 1              USD  OPI Nail Polish Lacquer Holiday Hello Kitty .5...
# 2              USD  L'oreal Colour Riche Lipstick 183 pink vinyl, ...
#
#    product_reviews_count  crawl_date crawl_time  rating_for_model  \
# 0                   22.0  2020-10-29   06:10:17          4.294622
# 1                    4.0  2020-07-30   02:49:53          3.000000
# 2                   38.0  2020-07-23   02:15:56          4.100000
#
#                               product_image_url_jpeg  popularity_score  \
# 0  https://i5.walmartimages.com/asr/44271b01-c56e...         13.465761
# 1  https://i5.walmartimages.com/asr/1d59e429-8acb...          4.828314
# 2  https://i5.walmartimages.com/asr/43ed681e-d913...         15.020603
#
#    brand_mean_rating  category_mean_rating  crawl_month  crawl_dayofweek
# 0           4.443212              4.294622           10                4
# 1           4.284840              3.000000            7                4
# 2           4.035227              4.021739            7                4

# %%
cols_to_round = ["popularity_score","category_mean_rating","rating_for_model" , "brand_mean_rating","product_reviews_count"]

def round_columns(df , columns , decimal = 2):
    df[columns] = df[columns].round(decimal)
    return df 


featured_dataset = round_columns(featured_dataset , cols_to_round)

# %%
featured_dataset.head(4)
# Out:
#    uniq_id  product_id                                   product_category  \
# 0     2612         971  Premium Beauty > Premium Makeup > Premium Lips...
# 1     3524        2947  Premium Beauty > Premium Makeup > Premium Nail...
# 2      219        4388  Beauty > Beauty by Top Brands > L'Oreal > L'Or...
# 3     4627        3845  Personal Care > Oral Care > Teeth Whitening > ...
#
#     product_brand                                       product_name  \
# 0            NARS       NARS Velvet Matte Lip Pencil, Endangered Red
# 1             OPI  OPI Nail Polish Lacquer Holiday Hello Kitty .5...
# 2   L'Oreal Paris        Loreal Colour Riche Lipstick 183 pink vinyl
# 3  Belle Chemical  Organic Coconut Activated Charcoal Powder - Fo...
#
#    product_price                                product_description  \
# 0          11.25
# 1          10.95
# 2           6.41       183 pink vinylLp Generic Loreal Paris Colou.
# 3           4.49  Activated Charcoal also known as activated car...
#
#   product_currency                                       product_tags  \
# 0              USD  NARS Velvet Matte Lip Pencil, Endangered Red, ...
# 1              USD  OPI Nail Polish Lacquer Holiday Hello Kitty .5...
# 2              USD  L'oreal Colour Riche Lipstick 183 pink vinyl, ...
# 3              USD  Organic Coconut Activated Charcoal Powder - Fo...
#
#    product_reviews_count  crawl_date crawl_time  rating_for_model  \
# 0                   22.0  2020-10-29   06:10:17              4.29
# 1                    4.0  2020-07-30   02:49:53              3.00
# 2                   38.0  2020-07-23   02:15:56              4.10
# 3                    7.0  2020-10-20   19:12:47              4.29
#
#                               product_image_url_jpeg  popularity_score  \
# 0  https://i5.walmartimages.com/asr/44271b01-c56e...             13.47
# 1  https://i5.walmartimages.com/asr/1d59e429-8acb...              4.83
# 2  https://i5.walmartimages.com/asr/43ed681e-d913...             15.02
# 3  https://i5.walmartimages.com/asr/b3cd3799-8646...              8.93
#
#    brand_mean_rating  category_mean_rating  crawl_month  crawl_dayofweek
# 0               4.44                  4.29           10                4
# 1               4.28                  3.00            7                4
# 2               4.04                  4.02            7                4
# 3               4.29                  4.29           10                2

# %% [markdown]
# ## Text Clenning

# %%
import re

# %%
## Now we will extract the categorical levels , which hep us to find the which category has most demand and all

# %%
categorical_levels = featured_dataset["product_category"].str.split(">")

featured_dataset["categorical_L1"] = categorical_levels.str[0]
featured_dataset["categorical_L2"] = categorical_levels.str[1]
featured_dataset["categorical_L3"] = categorical_levels.str[2]
featured_dataset["categorical_L4"] = categorical_levels.str[3]

# %%
## cleaning the text 
## converting into lower string and then removing the special characters and keeps only a-z ,
#0-9 and spaces and then replaces the multispaces with a single space

# %%
def text_cleaning(text):
    if pd.isna(text):
        return ""
        
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]"," ",text)
    text = re.sub(r"\s+"," ",text).strip()
    
    return text

# %%
columns = ["product_name", "product_tags", "product_category"]

for col in columns:
    featured_dataset[col] = featured_dataset[col].apply(text_cleaning)

# %%
featured_dataset
# Out:
#       uniq_id  product_id                                   product_category  \
# 0        2612         971  premium beauty premium makeup premium lips pre...
# 1        3524        2947  premium beauty premium makeup premium nail pol...
# 2         219        4388  beauty beauty by top brands l oreal l oreal ma...
# 3        4627        3845  personal care oral care teeth whitening charco...
# 4        1919        1578  premium beauty premium facial skincare premium...
# ...       ...         ...                                                ...
# 4995     3387        2026  premium beauty premium bath body premium body ...
# 4996     3489         688                   personal care sun care sunscreen
# 4997      592        1348  home appliances appliances parts accessories d...
# 4998     1042         996  personal care incontinence incontinence underwear
# 4999     3376        1925       personal care bath body body wash shower gel
#
#                product_brand  \
# 0                       NARS
# 1                        OPI
# 2              L'Oreal Paris
# 3             Belle Chemical
# 4                 StriVectin
# ...                      ...
# 4995                 Nu Skin
# 4996                   NO-AD
# 4997                  Finish
# 4998                 Attends
# 4999  Love Beauty and Planet
#
#                                            product_name  product_price  \
# 0           nars velvet matte lip pencil endangered red          11.25
# 1     opi nail polish lacquer holiday hello kitty 5o...          10.95
# 2           loreal colour riche lipstick 183 pink vinyl           6.41
# 3     organic coconut activated charcoal powder food...           4.49
# 4     strivectin overnight replenishing moisture mas...          22.98
# ...                                                 ...            ...
# 4995             nuskin epoch polishing bar soap 2 bars          36.99
# 4996                no ad products no ad sunblock 12 oz          19.98
# 4997  finish max in 1 powerball 24ct wrapper free di...          45.00
# 4998  attends healthcare products adult incontinent ...          71.46
# 4999  love beauty and planet body wash and cleansing...          20.49
#
#                                     product_description product_currency  \
# 0                                                                    USD
# 1                                                                    USD
# 2          183 pink vinylLp Generic Loreal Paris Colou.              USD
# 3     Activated Charcoal also known as activated car...              USD
# 4                                                                    USD
# ...                                                 ...              ...
# 4995                                                                 USD
# 4996  Sunblock, Continuous Spray, Sport, SPF 30, Sup...              USD
# 4997                                                                 USD
# 4998  58-63 Inch waist/hip Designed for extended use...              USD
# 4999  At Love Beauty and Planet we are committed to ...              USD
#
#                                            product_tags  \
# 0     nars velvet matte lip pencil endangered red wa...
# 1     opi nail polish lacquer holiday hello kitty 5o...
# 2     l oreal colour riche lipstick 183 pink vinyl w...
# 3     organic coconut activated charcoal powder food...
# 4     strivectin overnight replenishing moisture mas...
# ...                                                 ...
# 4995  nuskin epoch polishing bar soap 2 bars wal mar...
# 4996  no ad products no ad sunblock 12 oz wal mart w...
# 4997  finish max in 1 powerball 24ct wrapper free di...
# 4998  attends healthcare products adult incontinent ...
# 4999  love beauty and planet body wash and cleansing...
#
#       product_reviews_count  ...  \
# 0                     22.00  ...
# 1                      4.00  ...
# 2                     38.00  ...
# 3                      7.00  ...
# 4                      1.67  ...
# ...                     ...  ...
# 4995                   5.25  ...
# 4996                 167.22  ...
# 4997                 780.00  ...
# 4998                 170.67  ...
# 4999                 409.00  ...
#
#                                  product_image_url_jpeg popularity_score  \
# 0     https://i5.walmartimages.com/asr/44271b01-c56e...            13.47
# 1     https://i5.walmartimages.com/asr/1d59e429-8acb...             4.83
# 2     https://i5.walmartimages.com/asr/43ed681e-d913...            15.02
# 3     https://i5.walmartimages.com/asr/b3cd3799-8646...             8.93
# 4     https://i5.walmartimages.com/asr/02f72004-984b...             4.90
# ...                                                 ...              ...
# 4995  https://i5.walmartimages.com/asr/c09e3e71-59db...             7.72
# 4996  https://i5.walmartimages.com/asr/423e8b85-f0d7...            20.76
# 4997  https://i5.walmartimages.com/asr/51252773-7786...            31.30
# 4998  https://i5.walmartimages.com/asr/9b8deab6-8f88...            20.77
# 4999  https://i5.walmartimages.com/asr/fdd933ac-eda6...            26.47
#
#       brand_mean_rating category_mean_rating  crawl_month  crawl_dayofweek  \
# 0                  4.44                 4.29           10                4
# 1                  4.28                 3.00            7                4
# 2                  4.04                 4.02            7                4
# 3                  4.29                 4.29           10                2
# 4                  5.00                 5.00            8                3
# ...                 ...                  ...          ...              ...
# 4995               3.91                 4.21            7                3
# 4996               4.05                 4.05           11                3
# 4997               4.49                 4.70           12                2
# 4998               4.08                 4.04           11                3
# 4999               4.50                 4.53            7                3
#
#        categorical_L1             categorical_L2  \
# 0     Premium Beauty             Premium Makeup
# 1     Premium Beauty             Premium Makeup
# 2             Beauty       Beauty by Top Brands
# 3      Personal Care                  Oral Care
# 4     Premium Beauty    Premium Facial Skincare
# ...               ...                        ...
# 4995  Premium Beauty        Premium Bath & Body
# 4996   Personal Care                   Sun Care
# 4997            Home                 Appliances
# 4998   Personal Care               Incontinence
# 4999   Personal Care                Bath & Body
#
#                           categorical_L3             categorical_L4
# 0                          Premium Lips           Premium Lip Liner
# 1            Premium Nail Polish & Care           Premium Nail Kits
# 2                               L'Oreal              L'Oreal Makeup
# 3                       Teeth Whitening    Charcoal Teeth Whitening
# 4                     Premium Face Masks                        NaN
# ...                                  ...                        ...
# 4995   Premium Body Washes & Shower Gels                        NaN
# 4996                           Sunscreen                        NaN
# 4997     Appliances Parts & Accessories           Dishwasher Parts
# 4998              Incontinence Underwear                        NaN
# 4999              Body Wash & Shower Gel                        NaN
#
# [5000 rows x 23 columns]

# %%
featured_dataset.columns
# Out:
# Index(['uniq_id', 'product_id', 'product_category', 'product_brand',
#        'product_name', 'product_price', 'product_description',
#        'product_currency', 'product_tags', 'product_reviews_count',
#        'crawl_date', 'crawl_time', 'rating_for_model',
#        'product_image_url_jpeg', 'popularity_score', 'brand_mean_rating',
#        'category_mean_rating', 'crawl_month', 'crawl_dayofweek',
#        'categorical_L1', 'categorical_L2', 'categorical_L3', 'categorical_L4'],
#       dtype='object')

# %%
featured_dataset.to_csv("final_dataset.csv",index = False)
